# %%
#import operational data packages 
import pandas as pd 
import numpy as np 
import os

#Data visualtionation packages
import seaborn as sns
import matplotlib.pyplot as plt

#Data cleaning packages 
# %pip install pyjanitor
import janitor

# %%
#Change the working folder to easily read the files 
os.chdir("C:/Users/Owner/Documents/GitHub/air-quality/harrisburg-philly-aq/harrisburg-local-sites")
# %pwd
# Out:
# 'C:\\Users\\Owner\\Documents\\GitHub\\air-quality\\harrisburg-philly-aq\\harrisburg-local-sites'

# %%
#Upload the different files to the notebook before joining them
site_11_30 = pd.read_csv("DailySiteReport-11-30-2025.csv")
site_12_01 = pd.read_csv("DailySiteReport-12-01-2025.csv")
site_12_02 = pd.read_csv("DailySiteReport-12-02-2025.csv")
site_12_03 = pd.read_csv("DailySiteReport-12-03-2025.csv")
site_12_04 = pd.read_csv("DailySiteReport-12-04-2025.csv")
site_12_05 = pd.read_csv("DailySiteReport-12-05-2025.csv")
site_12_06 = pd.read_csv("DailySiteReport-12-06-2025.csv")

# %%
#Combine the above files and do some cleaning
harr_local_11_30_12_06 = pd.concat([site_11_30,site_12_01,
                                    site_12_02,site_12_03,
                                    site_12_04,site_12_05,site_12_06]).reset_index(drop=True)
harr_local_11_30_12_06

# %%
#Send the the clean files to be saved
harr_local_11_30_12_06.to_csv('harrisburg_local_11_30_12_06.csv')
